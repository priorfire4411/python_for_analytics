# %% [markdown]
# ### OOO
# * simple OOO example
# * classes - template of objects
# * objects - member or instance of class
# * classes can have
#     * characteristics/attribuets
#     * methods

# %%
# simple framework for a dog

class dog:
    def __init__(self,dog_color,dog_breed,dog_name):
        self.color = dog_color
        self.breed = dog_breed
        self.name = dog_name

# %%
dir(dog)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
my_dog = dog(dog_color = "blue", dog_breed = "sheperd", dog_name = "spot")

# %%
type(my_dog)
# Out:
# __main__.dog

# %%
my_dog.color
# Out:
# 'blue'

# %%
dir(my_dog)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'breed',
#  'color',
#  'name']

# %%
type(my_dog)


my_lazy_dog = [(10,'blue',10),('red','blue',10)]

# %%
my_lazy_dog[0][0]
# Out:
# 'red'

# %%
# simple framework for a dog
class dog:
    
    def __init__(self, breed, name,color=None):
        self.__color = color
        self.breed = breed
        self.name = name
        
    def speak(self):
        print("My color is " + self.__color)
        
    def change_color(self, carrot):
        self.color = carrot

# %%
my_dog = dog(color = "blue", breed = "sheperd", name = "spot")

# %%
dir(my_dog)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_dog__color',
#  'breed',
#  'change_color',
#  'name',
#  'speak']

# %%
my_dog.speak()
# Out:
# My color is blue

# %%
my_dog.color
# Out:
# 'red'

# %%
my_dog.change_color("red")
my_dog.speak()
# Out:
# My color is red

# %%
# simple framework for a dog
class dog:
    
    def __init__(self, color, breed, name):
        self.color = color
        self.breed = breed
        self.name = name
        self.distance = 0
        
    def walk(self, distance):
        self.distance += distance
    
    def peemeter(self):
        pee = 1 -  self.distance/50
        print("Pee Probability is ", pee)

# %%
my_dog = dog(color = "blue", breed = "sheperd", name = "spot")
my_dog.distance
# Out:
# 0

# %%
my_dog.walk(22)
my_dog.distance
my_dog.peemeter()
# Out:
# Pee Probability is  0.56

# %%
my_dog.walk(12)
my_dog.distance
my_dog.peemeter()
# Out:
# Pee Probability is  0.31999999999999995

# %%
my_dog.walk(18)
my_dog.distance
# Out:
# 35

# %% [markdown]
# Write a class dog with a variable distance that is private.
#
# with a function that walks the dog and returns an error if the value is negative

# %%
# simple framework for a dog
class dog:
    
    def __init__(self, color, breed, name):
        self.color = color
        self.breed = breed
        self.name = name
        self.__distance = 0
        
    def walk(self, distance):
        assert distance > 0, "Dude.. don't be lazy!!"
        self.__distance += distance
    
    def get_distance(self):
        print(self.__distance)
    
    def peemeter(self):
        pee = 1 -  self.__distance/50
        print("Pee Probability is ", pee)

# %%
my_dog = dog(color = "blue", breed = "sheperd", name = "spot")

# %%
my_dog.distance #distance is a private variable
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-113-9450ab14cff5> in <module>
# ----> 1 my_dog.distance #distance is a private variable
#
# AttributeError: 'dog' object has no attribute 'distance'

# %%
my_dog.walk(10)
my_dog.get_distance()
my_dog.walk(10)
my_dog.get_distance()
my_dog.walk(-10)
my_dog.get_distance()
# Out:
# 10
# 10
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-114-462306e3e0b3> in <module>
#       3 my_dog.walk(10)
#       4 my_dog.get_distance()
# ----> 5 my_dog.walk(-10)
#       6 my_dog.get_distance()
#
# <ipython-input-111-e06d8d5eea94> in walk(self, distance)
#       9     def walk(self, distance):
#      10         self.__distance = 0
# ---> 11         assert distance > 0, "Dude.. don't be lazy!!"
#      12         self.__distance += distance
#      13
#
# AssertionError: Dude.. don't be lazy!!

# %% [markdown]
# ## Inheritence
# * Inherit properties and functions from other objects

# %%
# simple framework for a dog
class dog:
    
    def __init__(self, color, breed, name):
        self.color = color
        self.breed = breed
        self.name = name
        self.__distance = 0
        
    def walk(self, distance):
        assert distance > 0, "Dude.. don't be lazy!!"
        self.__distance += distance
    
    def get_distance(self):
        print(self.__distance)
    
    def peemeter(self):
        pee = 1 -  self.__distance/50
        print("Pee Probability is ", pee)
        
class Retreiver(dog):
    pass

# %%
r =  Retreiver(color = "blue", breed = "retreiver", name = "Rex")

# %%
r.walk(10)

# %%
r.get_distance()
# Out:
# 10

# %%
# simple framework for a dog
class dog:
    
    def __init__(self, color, breed, name):
        self.color = color
        self.breed = breed
        self.name = name
        self.__distance = 0
        self.age = 2
        
    def walk(self, distance):
        assert distance > 0, "Dude.. don't be lazy!!"
        self.__distance += distance
    
    def get_distance(self):
        print(self.__distance)
    
    def peemeter(self):
        pee = 1 -  self.__distance/50
        print("Pee Probability is ", pee)

class vac():
    def __init__(self):
        self.vaccins_list=None
        
    def add_vaccin(self,name):
        self.vaccins_list.append(name)
    
    def get_vaccin(self):
        print(self.vaccins_list)


class retreiver(dog):
    def __init__(self, color, name):
        super().__init__(color=color, breed='Retriever',name=name)
    
    def __repr__(self):
        return "My name is {}".format(self.name)
        
    def speak(self):
        print("My name is {}".format(self.name))
        
    def blink182(self):
        print("My age is {}".format(self.age))

# %%
seb = retreiver('black','seb')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-287-3867047a28de> in <module>
# ----> 1 seb = retreiver('black','seb')
#
# <ipython-input-286-3b305b3e0620> in __init__(self, color, name)
#      33 class retreiver(dog, vac):
#      34     def __init__(self, color, name):
# ---> 35         super().__init__(dog, color=color, breed='Retriever',name=name)
#      36         super().__init__(vac)
#      37
#
# TypeError: __init__() got multiple values for argument 'color'

# %%
print(seb)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-285-93f9524fb212> in <module>
# ----> 1 print(seb)
#
# <ipython-input-283-8cc527b3b14f> in __repr__(self)
#      36
#      37     def __repr__(self):
# ---> 38         return "My name is {}".format(self.name)
#      39
#      40     def speak(self):
#
# AttributeError: 'retreiver' object has no attribute 'name'

# %%
r =  Dog(color = "blue", breed = "retreiver", name = "Rex")
r.speak()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-800ba7303882> in <module>
#       1 r =  Dog(color = "blue", breed = "retreiver", name = "Rex")
# ----> 2 r.speak()
#
# AttributeError: 'Dog' object has no attribute 'speak'

# %% [markdown]
# ## Class Methods
# * takes cls as the first input
# * bound to the class, not the instance of the object
# * can access class variables though not instance variables

# %%
class Dog:
    
    class_atr = 10
    
    @classmethod
    def speak(cls, speak):
        print(speak)
        
    @classmethod
    def add(cls,x,y):
        return x+y
    
    @classmethod
    def printer(cls):
        print(cls.class_atr)
        
    @classmethod
    def class_add(cls):
        cls.class_atr = cls.class_atr + 10
    
    def __init__(self, color, breed, name):
        self.color = color
        self.breed = breed
        self.name = name
        self.distance = 0
        
    def walk(self, distance):
        self.distance = Dog.add(self.distance, distance)

# %%
rex =  Dog(color = "blue", breed = "retreiver", name = "Rex")
thor =  Dog(color = "blue", breed = "retreiver", name = "thor")

# %%
rex.printer()
thor.class_add()
# Out:
# 10

# %%
rex.printer()
# Out:
# 20

# %%
rex.speak("say something")
# Out:
# say something

# %%
thor.speak("say something")
# Out:
# say something

# %%
r.walk(5)
r.walk(10)
r.distance
# Out:
# 30

# %% [markdown]
# ## Static Method
# * neither bound to the instance or class
# * no access to the instance or class attribuets
# * could be a standalone function but we want to keep it in the class
# * for instance, distance measures inside a KNN class.  then we can reference the functions when we have a fit method
# * aren't super useful due to limited access of information
# * utility type funciton

# %%
class Distance:
    
    @staticmethod
    def add(a,b):
        print(a+b)
    
    @staticmethod
    def sub(a,b):
        print(a-b)
    
    def __init__(self,x,y):
        self.x = x
        self.y = y
        
    def operate(self, how):
        if how == "add":
            Distance.add(self.x, self.y)
        else:
            Distance.sub(self.x, self.y)

# %%
d = Distance(10,5)

# %%
d.operate("add")
# Out:
# 15

# %%
d.operate("sub")
# Out:
# 5

# %% [markdown]
# ## Characteristics/Properties/Attributes
# * accessed using dot notation
# * methods are used using dot notation and parentheses ()
# * we can now read the sklearn documentation that much better
# * https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html
# * since sklearn documentation is consistent, we can easily look at any if the page and disect how the data structure works
#     * what methods we can use
#     * what characteristics we can access
#     * what params we can pass
# * https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# %% [markdown]
# ### DateTimes in Python
# * https://docs.python.org/3/library/datetime.html

# %%
import datetime


from datetime import datetime
from datetime import date

# %%
dir(datetime)
# Out:
# ['MAXYEAR',
#  'MINYEAR',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'date',
#  'datetime',
#  'datetime_CAPI',
#  'sys',
#  'time',
#  'timedelta',
#  'timezone',
#  'tzinfo']

# %% [markdown]
# #### Get Todays Date

# %%
today = datetime.today()
print(today)
# Out:
# 2020-04-22 20:08:46.587338

# %%
dir(today)
# Out:
# ['__add__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rsub__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  'ctime',
#  'day',
#  'fromisoformat',
#  'fromordinal',
#  'fromtimestamp',
#  'isocalendar',
#  'isoformat',
#  'isoweekday',
#  'max',
#  'min',
#  'month',
#  'replace',
#  'resolution',
#  'strftime',
#  'timetuple',
#  'today',
#  'toordinal',
#  'weekday',
#  'year']

# %%
today.month
# Out:
# 4

# %%
today.year
# Out:
# 2020

# %% [markdown]
# #### Weekdays start at monday and index at 0
# * 0:Monday
# * 1:Tuesday
# * 2:Wednesday
# * 3:Thursday
# * 4:Friday
# * 5:Saturday
# * 6:Sunday

# %%
today.weekday()
# Out:
# 2

# %%
dir(today)
# Out:
# ['__add__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rsub__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  'ctime',
#  'day',
#  'fromisoformat',
#  'fromordinal',
#  'fromtimestamp',
#  'isocalendar',
#  'isoformat',
#  'isoweekday',
#  'max',
#  'min',
#  'month',
#  'replace',
#  'resolution',
#  'strftime',
#  'timetuple',
#  'today',
#  'toordinal',
#  'weekday',
#  'year']

# %% [markdown]
# #### Get Time and Date Now

# %%
now = datetime.now()
print(now)
# Out:
# 2020-04-22 20:10:36.964919

# %%
dir(now)
# Out:
# ['__add__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rsub__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  'astimezone',
#  'combine',
#  'ctime',
#  'date',
#  'day',
#  'dst',
#  'fold',
#  'fromisoformat',
#  'fromordinal',
#  'fromtimestamp',
#  'hour',
#  'isocalendar',
#  'isoformat',
#  'isoweekday',
#  'max',
#  'microsecond',
#  'min',
#  'minute',
#  'month',
#  'now',
#  'replace',
#  'resolution',
#  'second',
#  'strftime',
#  'strptime',
#  'time',
#  'timestamp',
#  'timetuple',
#  'timetz',
#  'today',
#  'toordinal',
#  'tzinfo',
#  'tzname',
#  'utcfromtimestamp',
#  'utcnow',
#  'utcoffset',
#  'utctimetuple',
#  'weekday',
#  'year']

# %%
now.second
# Out:
# 36

# %%
now.minute
# Out:
# 10

# %%
now.hour
# Out:
# 20

# %%
now.day
# Out:
# 22

# %%
now.month
# Out:
# 4

# %%
now.year
# Out:
# 2020

# %%
now.weekday()
# Out:
# 2

# %% [markdown]
# <h3 style="color:blue">make a variable of the current date</h3>
# <p style="color:blue">- make a list with the weekdays</p>
# <p style="color:blue">- convert the weekday() integer to the actual date name</p>
# <p style="color:blue">- print the below, without hard coding it</p>
#
# create a class called converter that receives a date and language and overhauls the print (__repr__) to show the actual date name.

# %%
class converter():
    def __init__(self,language):
        self.lan = language

    def day_printer(self,language):
        if language=='EN':
            weekdays = {0:"Monday",
                1:"Tuesday",
                2:"Wednesday",
                3:"Thursday"}
            pretext="Today is "

        elif language=='PT':
            weekdays= {0:"Segunda",
                1:"Terça",
                2:"Quarta",
                3:"Quinta"}
            pretext="Hoje é "
        else:
            pretext="What?"
            weekdays=["0","1","2","3"]
        
        return pretext + weekdays[today.weekday()]
    
    def __repr__(self):
        x = self.day_printer(self.lan)
        return x
    

print(converter('EN'))
print(converter('PT'))
print(converter('ES'))
# Out:
# Today is Wednesday
# Hoje é Quarta
# What?2

# %% [markdown]
# #### Format Datetime output using strftime
# * (%y/%Y – Year)
# * (%a/%A- weekday)
# * (%b/%B- month)
# * (%d - day of month)
# * %c- indicates the local date and time
# * 12 hours time is declared [print now.strftime("%I:%M:%S %P) ]
# * 24 hours time is declared [print now.strftime("%H:%M")]

# %%
now = datetime.now()

# %%
print(now.strftime("%Y"))
print(now.strftime("%y"))
# Out:
# 2020
# 20

# %%
print(now.strftime("%A"))
print(now.strftime("%a"))
# Out:
# Wednesday
# Wed

# %%
print(now.strftime("%B"))
print(now.strftime("%b"))
# Out:
# April
# Apr

# %%
print(now.strftime("%D"))
print(now.strftime("%d"))
# Out:
# 04/22/20
# 22

# %%
print(now.strftime("%c"))
# Out:
# Wed Apr 22 20:45:33 2020

# %% [markdown]
# #### we can string these together

# %%
print(now.strftime("%Y-%B-%d"))
# Out:
# 2020-January-21

# %%
print(now.strftime("%Y,%B,%d"))
# Out:
# 2020,January,21

# %%
print(now.strftime("%y-%b-%d"))
# Out:
# 20-Jan-21

# %%
# I is the hour, # M is minutes, #S is seconds
# army time
print(now.strftime("%I%M"))
# Out:
# 0845

# %%
# 24 hour clock
print(now.strftime("%H:%M"))
# Out:
# 20:45

# %% [markdown]
# #### Use timedelta to add and subtract dates
# * does not support years, because the duration of a year depends on which year (for example, leap years have Feb 29)

# %%
from datetime import timedelta

# %%
print(datetime.now())
b = datetime(year=2020,month=1,day=31)

print(datetime.now() + timedelta(days=10, hours = 5, minutes = 15))
print(b)
# Out:
# 2020-04-22 20:52:51.292117
# 2020-05-03 02:07:51.292117
# 2020-01-31 00:00:00

# %%
print(datetime.now())
print(datetime.now() - timedelta(days=10, hours = 5, minutes = 15))
# Out:
# 2020-01-21 20:00:46.658815
# 2020-01-11 14:45:46.658815

# %%
print(datetime.now())
print(datetime.now() + timedelta(weeks=2))
# Out:
# 2020-01-21 20:01:03.819276
# 2020-02-04 20:01:03.819276

# %%
print(datetime.now())
print(datetime.now() - timedelta(weeks=2))
# Out:
# 2019-11-24 12:19:54.454511
# 2019-11-10 12:19:54.454799

# %%
a = datetime.now()

# %%
b = datetime.now()

# %%
b-a
# Out:
# datetime.timedelta(seconds=8, microseconds=624430)

# %%
# returns a datetime so we can extract info
x = datetime.now() - timedelta(weeks=2)
type(x)
# Out:
# datetime.datetime

# %%
x.year
# Out:
# 2020

# %%
x.month
# Out:
# 1

# %%
x.day
# Out:
# 7

# %%
x.weekday()
# Out:
# 1

# %% [markdown]
# <h3 style="color:blue">make a variable with the current date</h3>
# <p style="color:blue">- add/subtract a year</p>
# <p style="color:blue">- add subtract a year and 2 weeks</p>

# %% [markdown]
# ### Saving Objects in Python
# * serialization, marshaling, and flattening.
# * same—to save an object to a file for later retrieval
# * accomplishes this by writing the object as one long stream of bytes.
# * pickling also used to save models in sklearn
# * https://docs.python.org/3/library/pickle.html
# * https://scikit-learn.org/stable/modules/model_persistence.html

# %%
import pickle

# %%
test = ["a", "b"]

# %%
file = open('test_pickle.pkl', 'wb') 
pickle.dump(test, file)
file.close()

# %%
# delete from memory
del test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-161-a07cb10eeb0f> in <module>
#       1 # delete from memory
# ----> 2 del test
#
# NameError: name 'test' is not defined

# %%
file = open('test_pickle.pkl', 'rb') 
test = pickle.load(file)
file.close()

# %%
test
# Out:
# ['a', 'b']

# %% [markdown]
# #### using with

# %%
item = "some string I made"

# %%
with open("test_pickle.pkl", "wb") as file:
    pickle.dump(item, file)

# %%
del item
#item

# %%
with open("test_pickle.pkl", "rb") as file:
    item = pickle.load(file)

# %%
item
# Out:
# 'some string I made'

# %% [markdown]
# <h3 style="color:blue">make a python object</h3>
# <p style="color:blue">- save the object</p>
# <p style="color:blue">- delete the object from memory</p>
# <p style="color:blue">- reload it</p>

# %%
import shutil
import os
class cocumber:
    def __init__(self,test):
        with open('potato.pkl','wb') as f :
            pickle.dump(test, f)
        del test
        os.rename('potato.pkl', 'mashme3.txt')
        with open('meshme3.txt','rb') as f :    
            test = pickle.load(f)
        print(test)

# %%
cocumber('Staying ALive!!')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-190-24b9bf6d3f76> in <module>
# ----> 1 cocumber('Staying ALive!!')
#
# <ipython-input-189-df4c0cfbf515> in __init__(***failed resolving arguments***)
#       7         del test
#       8         os.rename('potato.pkl', 'mashme3.txt')
# ----> 9         with open('meshme3.txt','rb') as f :
#      10             test = pickle.load(f)
#      11         print(test)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'meshme3.txt'
